# %% [markdown]
# # Skenario 2 — Full Model (Semua Modul Atensi Aktif)
#
# Notebook ini melatih **AttentiveSkel-3D v2 versi penuh** sebagai *upper-bound* eksperimen.
# Seluruh tiga modul atensi diaktifkan secara bersamaan.
#
# | Modul | Status |
# |---|---|
# | Biomechanical Spatial Prior (BSP) | ✅ AKTIF |
# | Learned Spatial Attention | ✅ AKTIF |
# | Temporal Attention | ✅ AKTIF |
#
# **Prasyarat:** Jalankan `python src/data/v2/build_manifest.py` terlebih dahulu.

# %%
import sys
from pathlib import Path

# Tambahkan root proyek ke sys.path agar modul src dapat diimport
PROJECT_ROOT = Path("..").resolve().parent
sys.path.insert(0, str(PROJECT_ROOT))

import torch
import torch.nn as nn
import matplotlib.pyplot as plt

from src.data.v2.dataset import create_dataloaders_v2
from src.models.v2.model_per_frame import AttentiveSkel3DPerFrame, count_parameters
from src.models.v2.train import train_model_v2, evaluate_one_epoch_v2

print(f"[INFO] PyTorch : {torch.__version__}")
print(f"[INFO] CUDA    : {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"[INFO] GPU     : {torch.cuda.get_device_name(0)}")
# Out:
# [INFO] PyTorch : 2.5.1
# [INFO] CUDA    : True
# [INFO] GPU     : NVIDIA GeForce RTX 3060 Ti

# %%
# ============================================================
# Muat DataLoader dari manifest_v2.csv
# ============================================================
MANIFEST_V2 = PROJECT_ROOT / "data" / "processed" / "manifest_v2.csv"

train_loader, val_loader, test_loader = create_dataloaders_v2(
    csv_file    = MANIFEST_V2,
    batch_size  = 16,       # Ukuran batch standar
    train_ratio = 0.70,     # 70% data untuk pelatihan
    val_ratio   = 0.15,     # 15% untuk validasi, sisa 15% untuk test
    num_workers = 0,        # 0 di Windows untuk menghindari masalah multiprocessing
    random_seed = 42,       # Seed tetap untuk reproduktibilitas
)

# Verifikasi shape satu batch sebelum training dimulai
sample_input, sample_labels = next(iter(train_loader))
print(f"\n[VERIFIKASI] Shape input  : {sample_input.shape}   # (B, 64, 33, 3)")
print(f"[VERIFIKASI] Shape labels : {sample_labels.shape}  # (B, 64)")
# Out:
# Dataset split selesai (seed=42):
#   Train  :  340 sampel → 21 batch
#   Val    :   73 sampel → 5 batch
#   Test   :   74 sampel → 5 batch
#
# [VERIFIKASI] Shape input  : torch.Size([16, 64, 33, 3])   # (B, 64, 33, 3)
# [VERIFIKASI] Shape labels : torch.Size([16, 64])  # (B, 64)

# %%
# ============================================================
# Inisialisasi Model — SKENARIO 2: FULL MODEL (semua atensi aktif)
# ============================================================
model = AttentiveSkel3DPerFrame(
    num_classes            = 2,    # 0 = Benar, 1 = Salah
    use_spatial_prior      = True, # Biomechanical Spatial Prior AKTIF
    use_learned_spatial    = True, # Learned Spatial Attention AKTIF
    use_temporal_attention = True, # Temporal Attention AKTIF
)

print(f"[INFO] Skenario        : 2 — Full Model (Upper-Bound)")
print(f"[INFO] Parameter       : {count_parameters(model):,}")

# CrossEntropyLoss — menangani reshape (B,64,2)→(B*64,2) dilakukan di train.py
criterion = nn.CrossEntropyLoss()

# Adam lr=1e-3 — titik awal standar untuk dataset skala kecil
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# Verifikasi output shape model sebelum training
with torch.no_grad():
    dummy_out = model(sample_input)
print(f"[VERIFIKASI] Output shape  : {dummy_out.shape}  # Wajib (B, 64, 2)")
# Out:
# [INFO] Skenario        : 2 — Full Model (Upper-Bound)
# [INFO] Parameter       : 110,372
# [VERIFIKASI] Output shape  : torch.Size([16, 64, 2])  # Wajib (B, 64, 2)

# %%
# ============================================================
# Jalankan Training — train_model_v2 otomatis menggunakan CUDA
# ============================================================
SAVE_DIR = PROJECT_ROOT / "models" / "saved_models" / "v2"

history = train_model_v2(
    model         = model,
    train_loader  = train_loader,
    val_loader    = val_loader,
    criterion     = criterion,
    optimizer     = optimizer,
    num_epochs    = 100,
    save_dir      = SAVE_DIR,
    save_filename = "best_model_full.pth",  # Checkpoint Skenario 2
    verbose       = True,
)
# Out:
# [CUDA] GPU terdeteksi: NVIDIA GeForce RTX 3060 Ti
#
# ======================================================================
#   AttentiveSkel-3D v2 — Per-Frame Training
#   Device    : cuda
#   Epochs    : 100
#   Save path : D:\Data-Aji\KULIAH\Tugas-Akhir\AttentiveSkel3D-WeightTraining-PoC\models\saved_models\v2\best_model_full.pth
# ======================================================================
# Epoch [  1/100] ✓ | Train Loss: 0.6963 | Train Acc:  48.34% | Val Loss: 0.6817 | Val Acc:  66.74% | Waktu: 0.7s
# Epoch [  2/100] ✓ | Train Loss: 0.6563 | Train Acc:  66.55% | Val Loss: 0.6209 | Val Acc:  67.94% | Waktu: 0.4s
# Epoch [  3/100] ✓ | Train Loss: 0.5929 | Train Acc:  70.49% | Val Loss: 0.5352 | Val Acc:  71.43% | Waktu: 0.4s
# Epoch [  4/100] ✓ | Train Loss: 0.5264 | Train Acc:  74.39% | Val Loss: 0.5259 | Val Acc:  69.22% | Waktu: 0.4s
# Epoch [  5/100] ✓ | Train Loss: 0.4955 | Train Acc:  75.69% | Val Loss: 0.4602 | Val Acc:  75.43% | Waktu: 0.4s
# Epoch [  6/100] ✓ | Train Loss: 0.4500 | Train Acc:  79.18% | Val Loss: 0.4301 | Val Acc:  79.94% | Waktu: 0.4s
# Epoch [  7/100]   | Train Loss: 0.4256 | Train Acc:  80.72% | Val Loss: 0.4726 | Val Acc:  74.49% | Waktu: 0.4s
# Epoch [  8/100] ✓ | Train Loss: 0.3819 | Train Acc:  84.26% | Val Loss: 0.3720 | Val Acc:  83.69% | Waktu: 0.4s
# Epoch [  9/100]   | Train Loss: 0.3819 | Train Acc:  83.31% | Val Loss: 0.4641 | Val Acc:  74.06% | Waktu: 0.4s
# Epoch [ 10/100] ✓ | Train Loss: 0.3634 | Train Acc:  85.07% | Val Loss: 0.3605 | Val Acc:  85.66% | Waktu: 0.4s
# Epoch [ 11/100]   | Train Loss: 0.3685 | Train Acc:  84.34% | Val Loss: 0.3780 | Val Acc:  83.60% | Waktu: 0.4s
# Epoch [ 12/100] ✓ | Train Loss: 0.3442 | Train Acc:  85.77% | Val Loss: 0.3305 | Val Acc:  85.96% | Waktu: 0.4s
# Epoch [ 13/100]   | Train Loss: 0.3350 | Train Acc:  86.70% | Val Loss: 0.3356 | Val Acc:  86.75% | Waktu: 0.4s
# Epoch [ 14/100]   | Train Loss: 0.3046 | Train Acc:  88.39% | Val Loss: 0.4034 | Val Acc:  80.65% | Waktu: 0.4s
# Epoch [ 15/100] ✓ | Train Loss: 0.2971 | Train Acc:  88.07% | Val Loss: 0.3286 | Val Acc:  85.53% | Waktu: 0.4s
# Epoch [ 16/100] ✓ | Train Loss: 0.3020 | Train Acc:  88.43% | Val Loss: 0.2942 | Val Acc:  87.74% | Waktu: 0.4s
# Epoch [ 17/100]   | Train Loss: 0.3043 | Train Acc:  88.09% | Val Loss: 0.4007 | Val Acc:  82.34% | Waktu: 0.4s
# Epoch [ 18/100]   | Train Loss: 0.2936 | Train Acc:  88.48% | Val Loss: 0.2968 | Val Acc:  87.74% | Waktu: 0.4s
# Epoch [ 19/100]   | Train Loss: 0.2927 | Train Acc:  88.31% | Val Loss: 0.3659 | Val Acc:  84.16% | Waktu: 0.4s
# Epoch [ 20/100] ✓ | Train Loss: 0.2567 | Train Acc:  90.32% | Val Loss: 0.2650 | Val Acc:  88.85% | Waktu: 0.4s
# Epoch [ 21/100]   | Train Loss: 0.2310 | Train Acc:  91.49% | Val Loss: 0.2777 | Val Acc:  88.63% | Waktu: 0.4s
# Epoch [ 22/100]   | Train Loss: 0.2330 | Train Acc:  91.39% | Val Loss: 0.2830 | Val Acc:  88.36% | Waktu: 0.4s
# Epoch [ 23/100] ✓ | Train Loss: 0.2164 | Train Acc:  92.04% | Val Loss: 0.2513 | Val Acc:  89.75% | Waktu: 0.4s
# Epoch [ 24/100]   | Train Loss: 0.2169 | Train Acc:  92.05% | Val Loss: 0.2757 | Val Acc:  88.10% | Waktu: 0.4s
# Epoch [ 25/100] ✓ | Train Loss: 0.2350 | Train Acc:  91.20% | Val Loss: 0.2444 | Val Acc:  89.96% | Waktu: 0.4s
# Epoch [ 26/100]   | Train Loss: 0.2188 | Train Acc:  91.95% | Val Loss: 0.2653 | Val Acc:  89.04% | Waktu: 0.4s
# Epoch [ 27/100]   | Train Loss: 0.2189 | Train Acc:  91.96% | Val Loss: 0.2623 | Val Acc:  89.51% | Waktu: 0.4s
# Epoch [ 28/100]   | Train Loss: 0.2053 | Train Acc:  92.26% | Val Loss: 0.2495 | Val Acc:  89.77% | Waktu: 0.4s
# Epoch [ 29/100]   | Train Loss: 0.2269 | Train Acc:  91.70% | Val Loss: 0.3541 | Val Acc:  84.82% | Waktu: 0.4s
# Epoch [ 30/100]   | Train Loss: 0.2565 | Train Acc:  90.23% | Val Loss: 0.3263 | Val Acc:  86.96% | Waktu: 0.4s
# Epoch [ 31/100] ✓ | Train Loss: 0.2354 | Train Acc:  91.33% | Val Loss: 0.2339 | Val Acc:  90.28% | Waktu: 0.4s
# Epoch [ 32/100] ✓ | Train Loss: 0.2086 | Train Acc:  92.25% | Val Loss: 0.2303 | Val Acc:  91.22% | Waktu: 0.4s
# Epoch [ 33/100]   | Train Loss: 0.1954 | Train Acc:  92.70% | Val Loss: 0.2338 | Val Acc:  90.60% | Waktu: 0.4s
# Epoch [ 34/100]   | Train Loss: 0.2009 | Train Acc:  92.58% | Val Loss: 0.2663 | Val Acc:  89.28% | Waktu: 0.4s
# Epoch [ 35/100]   | Train Loss: 0.1898 | Train Acc:  93.27% | Val Loss: 0.2399 | Val Acc:  90.52% | Waktu: 0.4s
# Epoch [ 36/100]   | Train Loss: 0.1889 | Train Acc:  92.80% | Val Loss: 0.2988 | Val Acc:  86.88% | Waktu: 0.4s
# Epoch [ 37/100] ✓ | Train Loss: 0.2055 | Train Acc:  92.11% | Val Loss: 0.2273 | Val Acc:  91.67% | Waktu: 0.4s
# Epoch [ 38/100]   | Train Loss: 0.1955 | Train Acc:  92.90% | Val Loss: 0.2393 | Val Acc:  90.45% | Waktu: 0.4s
# Epoch [ 39/100]   | Train Loss: 0.1700 | Train Acc:  93.85% | Val Loss: 0.2419 | Val Acc:  90.30% | Waktu: 0.4s
# Epoch [ 40/100] ✓ | Train Loss: 0.1704 | Train Acc:  93.88% | Val Loss: 0.2142 | Val Acc:  91.99% | Waktu: 0.4s
# Epoch [ 41/100]   | Train Loss: 0.1702 | Train Acc:  93.75% | Val Loss: 0.2174 | Val Acc:  91.63% | Waktu: 0.4s
# Epoch [ 42/100]   | Train Loss: 0.1846 | Train Acc:  92.90% | Val Loss: 0.2349 | Val Acc:  91.67% | Waktu: 0.4s
# Epoch [ 43/100]   | Train Loss: 0.1856 | Train Acc:  93.13% | Val Loss: 0.2376 | Val Acc:  90.18% | Waktu: 0.4s
# Epoch [ 44/100]   | Train Loss: 0.1658 | Train Acc:  93.84% | Val Loss: 0.2224 | Val Acc:  91.59% | Waktu: 0.4s
# Epoch [ 45/100]   | Train Loss: 0.1461 | Train Acc:  94.65% | Val Loss: 0.2353 | Val Acc:  90.82% | Waktu: 0.4s
# Epoch [ 46/100]   | Train Loss: 0.1603 | Train Acc:  94.33% | Val Loss: 0.2305 | Val Acc:  91.25% | Waktu: 0.4s
# Epoch [ 47/100]   | Train Loss: 0.1584 | Train Acc:  93.93% | Val Loss: 0.2275 | Val Acc:  91.57% | Waktu: 0.4s
# Epoch [ 48/100]   | Train Loss: 0.1435 | Train Acc:  94.88% | Val Loss: 0.2378 | Val Acc:  91.48% | Waktu: 0.4s
# Epoch [ 49/100]   | Train Loss: 0.1489 | Train Acc:  94.57% | Val Loss: 0.2312 | Val Acc:  91.55% | Waktu: 0.4s
# Epoch [ 50/100]   | Train Loss: 0.1561 | Train Acc:  94.44% | Val Loss: 0.2329 | Val Acc:  91.05% | Waktu: 0.4s
# Epoch [ 51/100]   | Train Loss: 0.1665 | Train Acc:  93.86% | Val Loss: 0.2700 | Val Acc:  90.18% | Waktu: 0.4s
# Epoch [ 52/100]   | Train Loss: 0.1763 | Train Acc:  93.55% | Val Loss: 0.2332 | Val Acc:  91.65% | Waktu: 0.4s
# Epoch [ 53/100]   | Train Loss: 0.1528 | Train Acc:  94.35% | Val Loss: 0.2447 | Val Acc:  90.77% | Waktu: 0.4s
# Epoch [ 54/100]   | Train Loss: 0.1389 | Train Acc:  94.98% | Val Loss: 0.2588 | Val Acc:  90.52% | Waktu: 0.4s
# Epoch [ 55/100]   | Train Loss: 0.1436 | Train Acc:  94.76% | Val Loss: 0.2431 | Val Acc:  90.95% | Waktu: 0.4s
# Epoch [ 56/100]   | Train Loss: 0.1507 | Train Acc:  94.63% | Val Loss: 0.2238 | Val Acc:  91.89% | Waktu: 0.4s
# Epoch [ 57/100]   | Train Loss: 0.1434 | Train Acc:  94.81% | Val Loss: 0.2697 | Val Acc:  91.10% | Waktu: 0.4s
# Epoch [ 58/100]   | Train Loss: 0.1354 | Train Acc:  95.05% | Val Loss: 0.2440 | Val Acc:  91.63% | Waktu: 0.4s
# Epoch [ 59/100]   | Train Loss: 0.1238 | Train Acc:  95.70% | Val Loss: 0.2410 | Val Acc:  90.88% | Waktu: 0.4s
# Epoch [ 60/100]   | Train Loss: 0.1304 | Train Acc:  95.32% | Val Loss: 0.2454 | Val Acc:  90.77% | Waktu: 0.4s
# Epoch [ 61/100]   | Train Loss: 0.1323 | Train Acc:  95.02% | Val Loss: 0.2498 | Val Acc:  91.10% | Waktu: 0.4s
# Epoch [ 62/100]   | Train Loss: 0.1765 | Train Acc:  93.56% | Val Loss: 0.2364 | Val Acc:  91.44% | Waktu: 0.4s
# Epoch [ 63/100]   | Train Loss: 0.1401 | Train Acc:  95.22% | Val Loss: 0.2263 | Val Acc:  91.67% | Waktu: 0.4s
# Epoch [ 64/100]   | Train Loss: 0.1374 | Train Acc:  94.96% | Val Loss: 0.2653 | Val Acc:  91.14% | Waktu: 0.4s
# Epoch [ 65/100]   | Train Loss: 0.1281 | Train Acc:  95.54% | Val Loss: 0.2774 | Val Acc:  91.91% | Waktu: 0.4s
# Epoch [ 66/100]   | Train Loss: 0.1206 | Train Acc:  95.66% | Val Loss: 0.2564 | Val Acc:  90.84% | Waktu: 0.4s
# Epoch [ 67/100]   | Train Loss: 0.1276 | Train Acc:  95.45% | Val Loss: 0.2426 | Val Acc:  91.37% | Waktu: 0.4s
# Epoch [ 68/100]   | Train Loss: 0.1191 | Train Acc:  95.60% | Val Loss: 0.2398 | Val Acc:  91.80% | Waktu: 0.4s
# Epoch [ 69/100]   | Train Loss: 0.1219 | Train Acc:  95.85% | Val Loss: 0.2548 | Val Acc:  91.29% | Waktu: 0.4s
# Epoch [ 70/100]   | Train Loss: 0.1291 | Train Acc:  95.06% | Val Loss: 0.2418 | Val Acc:  92.12% | Waktu: 0.4s
# Epoch [ 71/100]   | Train Loss: 0.1195 | Train Acc:  95.73% | Val Loss: 0.2554 | Val Acc:  90.73% | Waktu: 0.4s
# Epoch [ 72/100]   | Train Loss: 0.1137 | Train Acc:  95.95% | Val Loss: 0.2922 | Val Acc:  90.58% | Waktu: 0.4s
# Epoch [ 73/100]   | Train Loss: 0.1186 | Train Acc:  95.75% | Val Loss: 0.2956 | Val Acc:  91.65% | Waktu: 0.4s
# Epoch [ 74/100]   | Train Loss: 0.1165 | Train Acc:  95.80% | Val Loss: 0.3333 | Val Acc:  90.48% | Waktu: 0.4s
# Epoch [ 75/100]   | Train Loss: 0.1102 | Train Acc:  96.03% | Val Loss: 0.3047 | Val Acc:  90.97% | Waktu: 0.4s
# Epoch [ 76/100]   | Train Loss: 0.1025 | Train Acc:  96.21% | Val Loss: 0.2739 | Val Acc:  90.60% | Waktu: 0.4s
# Epoch [ 77/100]   | Train Loss: 0.1159 | Train Acc:  95.94% | Val Loss: 0.2658 | Val Acc:  91.01% | Waktu: 0.4s
# Epoch [ 78/100]   | Train Loss: 0.1246 | Train Acc:  95.53% | Val Loss: 0.2646 | Val Acc:  90.77% | Waktu: 0.4s
# Epoch [ 79/100]   | Train Loss: 0.1252 | Train Acc:  95.48% | Val Loss: 0.2808 | Val Acc:  90.75% | Waktu: 0.4s
# Epoch [ 80/100]   | Train Loss: 0.1234 | Train Acc:  95.60% | Val Loss: 0.2729 | Val Acc:  90.26% | Waktu: 0.4s
# Epoch [ 81/100]   | Train Loss: 0.1159 | Train Acc:  95.74% | Val Loss: 0.2742 | Val Acc:  91.27% | Waktu: 0.4s
# Epoch [ 82/100]   | Train Loss: 0.1198 | Train Acc:  95.76% | Val Loss: 0.3039 | Val Acc:  91.18% | Waktu: 0.4s
# Epoch [ 83/100]   | Train Loss: 0.1145 | Train Acc:  95.74% | Val Loss: 0.2811 | Val Acc:  90.41% | Waktu: 0.4s
# Epoch [ 84/100]   | Train Loss: 0.1032 | Train Acc:  96.21% | Val Loss: 0.2874 | Val Acc:  91.07% | Waktu: 0.4s
# Epoch [ 85/100]   | Train Loss: 0.1021 | Train Acc:  96.41% | Val Loss: 0.2596 | Val Acc:  91.46% | Waktu: 0.4s
# Epoch [ 86/100]   | Train Loss: 0.1009 | Train Acc:  96.45% | Val Loss: 0.2399 | Val Acc:  92.04% | Waktu: 0.4s
# Epoch [ 87/100]   | Train Loss: 0.1064 | Train Acc:  96.33% | Val Loss: 0.2795 | Val Acc:  91.57% | Waktu: 0.4s
# Epoch [ 88/100]   | Train Loss: 0.1005 | Train Acc:  96.57% | Val Loss: 0.2819 | Val Acc:  90.92% | Waktu: 0.4s
# Epoch [ 89/100]   | Train Loss: 0.0938 | Train Acc:  96.72% | Val Loss: 0.2611 | Val Acc:  91.89% | Waktu: 0.4s
# Epoch [ 90/100]   | Train Loss: 0.0954 | Train Acc:  96.57% | Val Loss: 0.2574 | Val Acc:  91.59% | Waktu: 0.4s
# Epoch [ 91/100]   | Train Loss: 0.0859 | Train Acc:  96.87% | Val Loss: 0.2619 | Val Acc:  91.87% | Waktu: 0.4s
# Epoch [ 92/100]   | Train Loss: 0.0944 | Train Acc:  96.57% | Val Loss: 0.3496 | Val Acc:  90.84% | Waktu: 0.4s
# Epoch [ 93/100]   | Train Loss: 0.0935 | Train Acc:  96.57% | Val Loss: 0.2967 | Val Acc:  91.10% | Waktu: 0.4s
# Epoch [ 94/100]   | Train Loss: 0.0872 | Train Acc:  96.86% | Val Loss: 0.3255 | Val Acc:  90.22% | Waktu: 0.4s
# Epoch [ 95/100]   | Train Loss: 0.1033 | Train Acc:  96.14% | Val Loss: 0.2372 | Val Acc:  91.44% | Waktu: 0.4s
# Epoch [ 96/100]   | Train Loss: 0.1010 | Train Acc:  96.21% | Val Loss: 0.2848 | Val Acc:  91.91% | Waktu: 0.4s
# Epoch [ 97/100]   | Train Loss: 0.1086 | Train Acc:  96.04% | Val Loss: 0.2699 | Val Acc:  90.92% | Waktu: 0.4s
# Epoch [ 98/100]   | Train Loss: 0.0962 | Train Acc:  96.58% | Val Loss: 0.2896 | Val Acc:  91.57% | Waktu: 0.4s
# Epoch [ 99/100]   | Train Loss: 0.0905 | Train Acc:  96.81% | Val Loss: 0.2500 | Val Acc:  91.80% | Waktu: 0.4s
# Epoch [100/100]   | Train Loss: 0.0891 | Train Acc:  96.81% | Val Loss: 0.2783 | Val Acc:  91.20% | Waktu: 0.4s
# ======================================================================
#   Pelatihan selesai dalam 40.4 detik.
#   Epoch terbaik : 40  (Val Loss = 0.2142)
#   Model terbaik disimpan ke: D:\Data-Aji\KULIAH\Tugas-Akhir\AttentiveSkel3D-WeightTraining-PoC\models\saved_models\v2\best_model_full.pth
# ======================================================================

# %%
# ============================================================
# Visualisasi Kurva Training
# ============================================================
epochs = range(1, len(history["train_loss"]) + 1)
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Plot Loss
axes[0].plot(epochs, history["train_loss"], label="Train Loss", color="steelblue")
axes[0].plot(epochs, history["val_loss"],   label="Val Loss",   color="darkorange")
axes[0].axvline(x=history["best_epoch"], color="red", linestyle="--",
                label=f"Best Epoch ({history['best_epoch']})")
axes[0].set_title("Loss — Full Model (S2)")
axes[0].set_xlabel("Epoch")
axes[0].set_ylabel("CrossEntropyLoss")
axes[0].legend()
axes[0].grid(True)

# Plot Akurasi
axes[1].plot(epochs, [a * 100 for a in history["train_acc"]], label="Train Acc", color="steelblue")
axes[1].plot(epochs, [a * 100 for a in history["val_acc"]],   label="Val Acc",   color="darkorange")
axes[1].axvline(x=history["best_epoch"], color="red", linestyle="--",
                label=f"Best Epoch ({history['best_epoch']})")
axes[1].set_title("Akurasi — Full Model (S2)")
axes[1].set_xlabel("Epoch")
axes[1].set_ylabel("Akurasi (%)")
axes[1].legend()
axes[1].grid(True)

plt.suptitle("Skenario 2 — Full Model (Per-Frame)", fontsize=13)
plt.tight_layout()
plt.savefig(str(SAVE_DIR / "curve_s2_full_model.png"), dpi=150, bbox_inches="tight")
plt.show()

print(f"[DONE] Best Epoch   : {history['best_epoch']}")
print(f"[DONE] Best Val Loss: {history['best_val_loss']:.4f}")
print(f"[DONE] Best Val Acc : {history['val_acc'][history['best_epoch']-1]*100:.2f}%")
# Out:
# [DONE] Best Epoch   : 40
# [DONE] Best Val Loss: 0.2142
# [DONE] Best Val Acc : 91.99%

# %%
# ============================================================
# Evaluasi pada Test Set
# ============================================================
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model  = model.to(device)

test_loss, test_acc = evaluate_one_epoch_v2(
    model=model, loader=test_loader, criterion=criterion, device=device
)

print(f"[TEST SET — Skenario 2: Full Model]")
print(f"  Test Loss     : {test_loss:.4f}")
print(f"  Test Accuracy : {test_acc*100:.2f}%  (per prediksi frame)")
# Out:
# [TEST SET — Skenario 2: Full Model]
#   Test Loss     : 0.2972
#   Test Accuracy : 88.03%  (per prediksi frame)
